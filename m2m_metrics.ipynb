# %%
# !nvidia-smi
# Out:
# Mon Jul 20 19:11:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/Maaz-x14/m2m100-roman-deploy.git
# %cd m2m100-roman-deploy/
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'm2m100-roman-deploy'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 179 (delta 81), reused 153 (delta 55), pack-reused 0 (from 0)
# Receiving objects: 100% (179/179), 19.16 MiB | 20.31 MiB/s, done.
# Resolving deltas: 100% (81/81), done.
# /content/m2m100-roman-deploy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 40.1 MB/s eta 0:00:00

# %%
from google.colab import files
uploaded = files.upload()  # select your fine_tuned_model.zip

import zipfile, os
zip_name = list(uploaded.keys())[0]
with zipfile.ZipFile(zip_name, 'r') as z:
    z.extractall('.')

# defensive check for nested-folder zips
if os.path.exists('fine_tuned_model/fine_tuned_model'):
    import shutil
    shutil.move('fine_tuned_model/fine_tuned_model', 'fine_tuned_model_tmp')
    shutil.rmtree('fine_tuned_model')
    shutil.move('fine_tuned_model_tmp', 'fine_tuned_model')

assert os.path.exists('fine_tuned_model/adapter_config.json'), "Path structure wrong — check zip contents"
print("Model files:", os.listdir('fine_tuned_model'))
# Out:
#      <input type="file" id="files-db25330e-9519-4da7-a7b7-dad709d1d68d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db25330e-9519-4da7-a7b7-dad709d1d68d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()  # select bench_phase2.py AND run_sweep.py
# Out:
#      <input type="file" id="files-5ebde6ce-3a89-4cbe-b6a8-26e6d551a952" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ebde6ce-3a89-4cbe-b6a8-26e6d551a952">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install httpx -q

# %%
# !python run_sweep.py
# Out:
# Starting sweep: 12 combinations (batch sizes [8, 16, 32, 64] x wait_ms [20, 50, 100])
#
#
# ######################################################################
# # [1/12] batch=8_wait=20
# ######################################################################
# Waiting for server to become healthy...
#   Server healthy.
#   CONFIG_LABEL set to 'batch=8_wait=20' in bench_phase2.py
#   Running benchmark...
# ...
# Phase 2 Benchmark — concurrent HTTP load (real server)
# Config under test: batch=8_wait=20
# ...
# GPU memory before test: 1377.0 MB
#
# Server healthy at http://localhost:2000
#
# -- concurrency=1 --
#   per-request latency   p50=0.376s  p95=0.401s  p99=0.407s
#   round wall-time       p50=0.376s  p95=0.401s
#   effective throughput  2.65 req/s (at this concurrency level)
#   GPU memory (sampled)  1385.0 MB
#
# -- concurrency=2 --
#   per-request latency   p50=0.375s  p95=0.403s  p99=0.403s
#   round wall-time       p50=0.375s  p95=0.399s
# ...
